# %% [markdown]
# 1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.2
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 6
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 7
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 8
#
# ![image.png](attachment:image.png)
